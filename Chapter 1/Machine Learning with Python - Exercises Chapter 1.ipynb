# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1. Visit the UCI Repository $https://archive.ics.uci.edu/$. Read the description of the data and download the Mushroom data set $agaricus-lepiota.data$. Using pandas, read the data into a DataFrame called mushroom, $via read_csv$.
#
# ### (a) How many features are in this data set?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Read file

mush = pd.read_csv('agaricus-lepiota.data')
mush
# Out:
#       p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0     e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1     e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2     p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3     e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4     e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
# ...  .. .. .. .. ..  .. .. ..  .. ..  ...  .. ..  ..  ..  .. ..  ..  ..  .. ..
# 8118  e  k  s  n  f   n  a  c   b  y  ...   s  o   o   p   o  o   p   b   c  l
# 8119  e  x  s  n  f   n  a  c   b  y  ...   s  o   o   p   n  o   p   b   v  l
# 8120  e  f  s  n  f   n  a  c   b  n  ...   s  o   o   p   o  o   p   b   c  l
# 8121  p  k  y  n  f   y  f  c   n  b  ...   k  w   w   p   w  o   e   w   v  l
# 8122  e  x  s  n  f   n  a  c   b  y  ...   s  o   o   p   o  o   p   o   c  l
#
# ...

# %%
mush.shape
#We have 23 features
# Out:
# (8123, 23)

# %% [markdown]
# ### (b) What are the initial names and types of the features?

# %%
mush.describe

#These represent qualitative variables
# Out:
# <bound method NDFrame.describe of       p  x  s  n  t p.1  f  c n.1  k  ... s.2  w w.1 p.2 w.2  o p.3 k.1 s.3  u
# 0     e  x  s  y  t   a  f  c   b  k  ...   s  w   w   p   w  o   p   n   n  g
# 1     e  b  s  w  t   l  f  c   b  n  ...   s  w   w   p   w  o   p   n   n  m
# 2     p  x  y  w  t   p  f  c   n  n  ...   s  w   w   p   w  o   p   k   s  u
# 3     e  x  s  g  f   n  f  w   b  k  ...   s  w   w   p   w  o   e   n   a  g
# 4     e  x  y  y  t   a  f  c   b  n  ...   s  w   w   p   w  o   p   k   n  g
# ...  .. .. .. .. ..  .. .. ..  .. ..  ...  .. ..  ..  ..  .. ..  ..  ..  .. ..
# 8118  e  k  s  n  f   n  a  c   b  y  ...   s  o   o   p   o  o   p   b   c  l
# 8119  e  x  s  n  f   n  a  c   b  y  ...   s  o   o   p   n  o   p   b   v  l
# 8120  e  f  s  n  f   n  a  c   b  n  ...   s  o   o   p   o  o   p   b   c  l
# 8121  p  k  y  n  f   y  f  c   n  b  ...   k  w   w   p   w  o   e   w   v  l
# ...

# %% [markdown]
# ### (c) Rename the first feature (index $0$) to 'edibility' and the sixth feature (index $5$) to 'odor' [Hint: the column names in pandas are immutable; so individual columns cannot be modified directly. However it is possible to assign the entire column names listviamushroom.columns = newcols.]

# %%
mush.index
# Out:
# RangeIndex(start=0, stop=8123, step=1)

# %%
mush.columns
# Out:
# Index(['p', 'x', 's', 'n', 't', 'p.1', 'f', 'c', 'n.1', 'k', 'e', 'e.1', 's.1',
#        's.2', 'w', 'w.1', 'p.2', 'w.2', 'o', 'p.3', 'k.1', 's.3', 'u'],
#       dtype='object')

# %%
#Change columns and index

mush.columns=['edebility', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-atachment', 'gill-spacing', 'gill-size',
             'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', ' stalk-surface-below-ring',
             'stalk-color-above-ring', 'stalk-color-below-ring', ' veil-type', 'veil-color', 'ring-number', 'ring-type',
             'spore-print-color', 'population', 'habitat']
mush
# Out:
#      edebility cap-shape cap-surface cap-color bruises odor gill-atachment  \
# 0            e         x           s         y       t    a              f
# 1            e         b           s         w       t    l              f
# 2            p         x           y         w       t    p              f
# 3            e         x           s         g       f    n              f
# 4            e         x           y         y       t    a              f
# ...        ...       ...         ...       ...     ...  ...            ...
# 8118         e         k           s         n       f    n              a
# 8119         e         x           s         n       f    n              a
# 8120         e         f           s         n       f    n              a
# 8121         p         k           y         n       f    y              f
# 8122         e         x           s         n       f    n              a
#
# ...

# %% [markdown]
# ### (d) The 6th column lists the various odors of the mushrooms: encoded as 'a', 'c', . . . . Replace these with the names 'almond', 'creosote', etc. (categories corresponding to each letter can be found on the website). Also replace the 'edibility' categories 'e' and 'p' with 'edible' and 'poisonous'.

# %%
#Let's create a dictionary with the old and new variables

DICT6 = {'a':'almond', 'c':'creasote'}
mush['odor'] = mush['odor'].replace(DICT6).astype('category')

DICT1 = {'e':'edible', 'p':'poisonous'}
mush['edebility'] = mush['edebility'].replace(DICT1).astype('category')

# %%
mush
# Out:
#       edebility cap-shape cap-surface cap-color bruises    odor  \
# 0        edible         x           s         y       t  almond
# 1        edible         b           s         w       t       l
# 2     poisonous         x           y         w       t       p
# 3        edible         x           s         g       f       n
# 4        edible         x           y         y       t  almond
# ...         ...       ...         ...       ...     ...     ...
# 8118     edible         k           s         n       f       n
# 8119     edible         x           s         n       f       n
# 8120     edible         f           s         n       f       n
# 8121  poisonous         k           y         n       f       y
# 8122     edible         x           s         n       f       n
#
#      gill-atachment gill-spacing gill-size gill-color  ...  \
# 0                 f            c         b          k  ...
# 1                 f            c         b          n  ...
# ...

# %% [markdown]
# ### e) Make a contingency table cross-tabulating 'edibility' and 'odor'

# %%
pd.crosstab(mush.edebility, mush.odor)
# Out:
# odor       almond  creasote     f    l   m     n    p    s    y
# edebility
# edible        400         0     0  400   0  3408    0    0    0
# poisonous       0       192  2160    0  36   120  255  576  576

# %% [markdown]
# ### (f) Which mushroom odors should be avoided, when gathering mushrooms for consumption?
#
#
# ### R/: We should avoid the creasote, f, m, p, a, and y.

# %% [markdown]
# ### (g) What proportion of odorless mushroom samples were safe to eat?

# %%
#Let's change the names of the columns

DICT6 = {'a':'almond', 'c':'creasote', 'l':'anise', 'y':'fishy', 'f':'foul', 
        'm':'musty', 'n':'none', 'p':'pungent', 's':'spicy'}
mush['odor'] = mush['odor'].replace(DICT6).astype('category')

# %%
mush
# Out:
#       edebility cap-shape cap-surface cap-color bruises     odor  \
# 0        edible         x           s         y       t   almond
# 1        edible         b           s         w       t    anise
# 2     poisonous         x           y         w       t  pungent
# 3        edible         x           s         g       f     none
# 4        edible         x           y         y       t   almond
# ...         ...       ...         ...       ...     ...      ...
# 8118     edible         k           s         n       f     none
# 8119     edible         x           s         n       f     none
# 8120     edible         f           s         n       f     none
# 8121  poisonous         k           y         n       f    fishy
# 8122     edible         x           s         n       f     none
#
#      gill-atachment gill-spacing gill-size gill-color  ...  \
# 0                 f            c         b          k  ...
# 1                 f            c         b          n  ...
# ...

# %%
edandor = pd.crosstab(mush.edebility, mush.odor)

# %%
edandor
# Out:
# odor       almond  anise  creasote  fishy  foul  musty  none  pungent  spicy
# edebility
# edible        400    400         0      0     0      0  3408        0      0
# poisonous       0      0       192    576  2160     36   120      255    576

# %%
propor = (edandor['none']['edible']/edandor['none'].sum())*100

print('The proportion of edible non-odor mushroms is: {0:0.0f}%'.format(propor))
# Out:
# The proportion of edible non-odor mushroms is: 97%
